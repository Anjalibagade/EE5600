# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
y=np.linspace(-1,1,1000)

# %%
# Vertex of parabola
V = np.array([0,0])

# %%
# Focus point of parabola
F = np.array([0.25,0])

# %%
# Directrix poinr of parabola
D = np.array([-0.25,0])

# %%
x=y**2

# %%
plt.text(V[0] * (1 - 0.1), V[1] * (1 - 0.2) , '(0,0)')
plt.plot(0,0,'ro',label='Vertex point')
plt.plot(x,y)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.grid()
plt.legend(loc='best')
plt.show()
